# %%
pos={'status': 'success',
 'data': {'net': [{'tradingsymbol': 'NIFTY2332317300CE',
    'exchange': 'NFO',
    'instrument_token': 10725890,
    'product': 'NRML',
    'quantity': 50,
    'overnight_quantity': 50,
    'multiplier': 1,
    'average_price': 146.95,
    'close_price': 128.75,
    'last_price': 82.15,
    'value': -7347.499999999999,
    'pnl': -3239.999999999999,
    'm2m': -2330,
    'unrealised': -3239.999999999999,
    'realised': 0,
    'buy_quantity': 50,
    'buy_price': 146.95,
    'buy_value': 7347.499999999999,
    'buy_m2m': 6437.5,
    'sell_quantity': 0,
    'sell_price': 0,
    'sell_value': 0,
    'sell_m2m': 0,
    'day_buy_quantity': 0,
    'day_buy_price': 0,
    'day_buy_value': 0,
    'day_sell_quantity': 0,
    'day_sell_price': 0,
    'day_sell_value': 0},
   {'tradingsymbol': 'ACC',
    'exchange': 'NSE',
    'instrument_token': 5633,
    'product': 'MIS',
    'quantity': -3,
    'overnight_quantity': 0,
    'multiplier': 1,
    'average_price': 1740.33,
    'close_price': 0,
    'last_price': 1697.55,
    'value': 5193.95,
    'pnl': 101.30000000000018,
    'm2m': 101.30000000000018,
    'unrealised': 101.30000000000018,
    'realised': 0,
    'buy_quantity': 2,
    'buy_price': 1753.85,
    'buy_value': 3507.7,
    'buy_m2m': 3507.7,
    'sell_quantity': 5,
    'sell_price': 1740.33,
    'sell_value': 8701.65,
    'sell_m2m': 8701.65,
    'day_buy_quantity': 2,
    'day_buy_price': 1753.85,
    'day_buy_value': 3507.7,
    'day_sell_quantity': 5,
    'day_sell_price': 1740.33,
    'day_sell_value': 8701.65},
   {'tradingsymbol': 'NIFTY2331617100PE',
    'exchange': 'NFO',
    'instrument_token': 14230786,
    'product': 'NRML',
    'quantity': 0,
    'overnight_quantity': 0,
    'multiplier': 1,
    'average_price': 0,
    'close_price': 0,
    'last_price': 120.95,
    'value': -497.5,
    'pnl': -497.5,
    'm2m': -497.5,
    'unrealised': -497.5,
    'realised': 0,
    'buy_quantity': 50,
    'buy_price': 82.4,
    'buy_value': 4120,
    'buy_m2m': 4120,
    'sell_quantity': 50,
    'sell_price': 72.45,
    'sell_value': 3622.5,
    'sell_m2m': 3622.5,
    'day_buy_quantity': 50,
    'day_buy_price': 82.4,
    'day_buy_value': 4120,
    'day_sell_quantity': 50,
    'day_sell_price': 72.45,
    'day_sell_value': 3622.5}],
  'day': [{'tradingsymbol': 'ACC',
    'exchange': 'NSE',
    'instrument_token': 5633,
    'product': 'MIS',
    'quantity': -3,
    'overnight_quantity': 0,
    'multiplier': 1,
    'average_price': 1740.33,
    'close_price': 0,
    'last_price': 1697.55,
    'value': 5193.95,
    'pnl': 101.30000000000018,
    'm2m': 101.30000000000018,
    'unrealised': 101.30000000000018,
    'realised': 0,
    'buy_quantity': 2,
    'buy_price': 1753.85,
    'buy_value': 3507.7,
    'buy_m2m': 3507.7,
    'sell_quantity': 5,
    'sell_price': 1740.33,
    'sell_value': 8701.65,
    'sell_m2m': 8701.65,
    'day_buy_quantity': 2,
    'day_buy_price': 1753.85,
    'day_buy_value': 3507.7,
    'day_sell_quantity': 5,
    'day_sell_price': 1740.33,
    'day_sell_value': 8701.65},
   {'tradingsymbol': 'NIFTY2331617100PE',
    'exchange': 'NFO',
    'instrument_token': 14230786,
    'product': 'NRML',
    'quantity': 0,
    'overnight_quantity': 0,
    'multiplier': 1,
    'average_price': 0,
    'close_price': 0,
    'last_price': 120.95,
    'value': -497.5,
    'pnl': -497.5,
    'm2m': -497.5,
    'unrealised': -497.5,
    'realised': 0,
    'buy_quantity': 50,
    'buy_price': 82.4,
    'buy_value': 4120,
    'buy_m2m': 4120,
    'sell_quantity': 50,
    'sell_price': 72.45,
    'sell_value': 3622.5,
    'sell_m2m': 3622.5,
    'day_buy_quantity': 50,
    'day_buy_price': 82.4,
    'day_buy_value': 4120,
    'day_sell_quantity': 50,
    'day_sell_price': 72.45,
    'day_sell_value': 3622.5}]}}



orders={'status': 'success',
 'data': [{'placed_by': 'MD1238',
   'order_id': '230314400309681',
   'exchange_order_id': '1100000008803145',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 09:26:20',
   'exchange_update_timestamp': '2023-03-14 09:26:20',
   'exchange_timestamp': '2023-03-14 09:26:20',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NFO',
   'tradingsymbol': 'NIFTY2331617100PE',
   'instrument_token': 14230786,
   'order_type': 'MARKET',
   'transaction_type': 'BUY',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'NRML',
   'quantity': 50,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 82.4,
   'filled_quantity': 50,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '3106Xsxhwtlzaoxjo'},
  {'placed_by': 'MD1238',
   'order_id': '230314400322821',
   'exchange_order_id': '1100000009325858',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 09:27:08',
   'exchange_update_timestamp': '2023-03-14 09:27:08',
   'exchange_timestamp': '2023-03-14 09:27:08',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NFO',
   'tradingsymbol': 'NIFTY2331617100PE',
   'instrument_token': 14230786,
   'order_type': 'MARKET',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'NRML',
   'quantity': 50,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 72.45,
   'filled_quantity': 50,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '3106Xidgvtvlnwqbo'},
  {'placed_by': 'MD1238',
   'order_id': '230314402395058',
   'exchange_order_id': '1000000018441402',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 13:28:11',
   'exchange_update_timestamp': '2023-03-14 13:28:11',
   'exchange_timestamp': '2023-03-14 13:28:11',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'MARKET',
   'transaction_type': 'BUY',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 1,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 1753.7,
   'filled_quantity': 1,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590X1dzm5WqWkfs9'},
  {'placed_by': 'MD1238',
   'order_id': '230314402403763',
   'exchange_order_id': '1000000018518598',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 13:29:27',
   'exchange_update_timestamp': '2023-03-14 13:29:26',
   'exchange_timestamp': '2023-03-14 13:29:26',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'MARKET',
   'transaction_type': 'BUY',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 1,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 1754,
   'filled_quantity': 1,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590Xj6F9dDdt6LQl'},
  {'placed_by': 'MD1238',
   'order_id': '230314402472365',
   'exchange_order_id': '1000000019050111',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 13:36:06',
   'exchange_update_timestamp': '2023-03-14 13:36:06',
   'exchange_timestamp': '2023-03-14 13:36:06',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'MARKET',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 1,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 1752.55,
   'filled_quantity': 1,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590Xj2Ev9JxWMHGI'},
  {'placed_by': 'MD1238',
   'order_id': '230314402562398',
   'exchange_order_id': '1000000020096576',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 13:51:33',
   'exchange_update_timestamp': '2023-03-14 13:51:33',
   'exchange_timestamp': '2023-03-14 13:51:33',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'MARKET',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 1,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 1740.35,
   'filled_quantity': 1,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590X9sGEYVrMNybs'},
  {'placed_by': 'MD1238',
   'order_id': '230314402613507',
   'exchange_order_id': '1000000020576658',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 13:59:03',
   'exchange_update_timestamp': '2023-03-14 13:59:03',
   'exchange_timestamp': '2023-03-14 13:59:03',
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'LIMIT',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 1,
   'disclosed_quantity': 0,
   'price': 1700,
   'trigger_price': 0,
   'average_price': 1739.55,
   'filled_quantity': 1,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590XdSW3sDfv71c1'},
  {'placed_by': 'MD1238',
   'order_id': '230314402615764',
   'exchange_order_id': '1000000020612064',
   'parent_order_id': None,
   'status': 'COMPLETE',
   'status_message': None,
   'status_message_raw': None,
   'order_timestamp': '2023-03-14 14:02:48',
   'exchange_update_timestamp': '2023-03-14 14:02:48',
   'exchange_timestamp': '2023-03-14 14:02:48',
   'variety': 'regular',
   'modified': True,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'MARKET',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 2,
   'disclosed_quantity': 0,
   'price': 0,
   'trigger_price': 0,
   'average_price': 1734.6,
   'filled_quantity': 2,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590XxRgfqwbYGWKc'},
  {'placed_by': 'MD1238',
   'order_id': '230314402697293',
   'exchange_order_id': None,
   'parent_order_id': None,
   'status': 'REJECTED',
   'status_message': 'Insufficient funds. Required margin is 3601568.74 but available margin is 38324.40. Check the orderbook for open orders.',
   'status_message_raw': 'RMS:Margin Exceeds,Required:3601568.74, Available:38324.40 for entity account-MD1238 across exchange across segment across product ',
   'order_timestamp': '2023-03-14 14:13:27',
   'exchange_update_timestamp': None,
   'exchange_timestamp': None,
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'LIMIT',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 10000,
   'disclosed_quantity': 0,
   'price': 1800,
   'trigger_price': 0,
   'average_price': 0,
   'filled_quantity': 0,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '31590XvurKcZGiysmE'},
  {'placed_by': 'MD1238',
   'order_id': '230314402734021',
   'exchange_order_id': None,
   'parent_order_id': None,
   'status': 'REJECTED',
   'status_message': 'Insufficient funds. Required margin is 3601568.74 but available margin is 38324.40. Check the orderbook for open orders.',
   'status_message_raw': 'RMS:Margin Exceeds,Required:3601568.74, Available:38324.40 for entity account-MD1238 across exchange across segment across product ',
   'order_timestamp': '2023-03-14 14:17:38',
   'exchange_update_timestamp': None,
   'exchange_timestamp': None,
   'variety': 'regular',
   'modified': False,
   'exchange': 'NSE',
   'tradingsymbol': 'ACC',
   'instrument_token': 5633,
   'order_type': 'LIMIT',
   'transaction_type': 'SELL',
   'validity': 'DAY',
   'validity_ttl': 0,
   'product': 'MIS',
   'quantity': 10000,
   'disclosed_quantity': 0,
   'price': 1800,
   'trigger_price': 0,
   'average_price': 0,
   'filled_quantity': 0,
   'pending_quantity': 0,
   'cancelled_quantity': 0,
   'market_protection': 0,
   'meta': {},
   'tag': None,
   'guid': '01XsejXyudwMCOa'}]}
